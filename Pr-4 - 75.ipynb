# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('BostonHousing.csv')

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.isnull()
# Out:
#       crim     zn  indus   chas    nox     rm    age    dis    rad    tax  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
#      ptratio      b  lstat   medv
# 0      False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.dropna()
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
x = df.drop('chas', axis = 1)

# %%
y = df['tax']

# %%
x.shape
# Out:
# (506, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_train = train_test_split(x,y,random_state = 0, test_size = 0.2)

# %%
x_train
# Out:
#          crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 220   0.35809   0.0   6.20  0.507  6.951  88.5  2.8617    8  307     17.4
# 71    0.15876   0.0  10.81  0.413  5.961  17.5  5.2873    4  305     19.2
# 240   0.11329  30.0   4.93  0.428  6.897  54.3  6.3361    6  300     16.6
# 6     0.08829  12.5   7.87  0.524  6.012  66.6  5.5605    5  311     15.2
# 417  25.94060   0.0  18.10  0.679  5.304  89.1  1.6475   24  666     20.2
# ..        ...   ...    ...    ...    ...   ...     ...  ...  ...      ...
# 323   0.28392   0.0   7.38  0.493  5.708  74.3  4.7211    5  287     19.6
# 192   0.08664  45.0   3.44  0.437  7.178  26.3  6.4798    5  398     15.2
# 117   0.15098   0.0  10.01  0.547  6.021  82.6  2.7474    6  432     17.8
# 47    0.22927   0.0   6.91  0.448  6.030  85.5  5.6894    3  233     17.9
# 172   0.13914   0.0   4.05  0.510  5.572  88.5  2.5961    5  296     16.6
#
#           b  lstat  medv
# 220  391.70   9.71  26.7
# 71   376.94   9.88  21.7
# ...

# %%
x_train.head()
# Out:
#          crim    zn  indus    nox     rm   age     dis  rad  tax  ptratio  \
# 220   0.35809   0.0   6.20  0.507  6.951  88.5  2.8617    8  307     17.4
# 71    0.15876   0.0  10.81  0.413  5.961  17.5  5.2873    4  305     19.2
# 240   0.11329  30.0   4.93  0.428  6.897  54.3  6.3361    6  300     16.6
# 6     0.08829  12.5   7.87  0.524  6.012  66.6  5.5605    5  311     15.2
# 417  25.94060   0.0  18.10  0.679  5.304  89.1  1.6475   24  666     20.2
#
#           b  lstat  medv
# 220  391.70   9.71  26.7
# 71   376.94   9.88  21.7
# 240  391.25  11.38  22.0
# 6    395.60  12.43  22.9
# 417  127.36  26.64  10.4

# %%
x_train.shape
# Out:
# (404, 13)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
df.iloc[379]
# Out:
# crim        17.8667
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6710
# rm           6.2230
# age        100.0000
# dis          1.3861
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# b          393.7400
# lstat       21.7800
# medv        10.2000
# Name: 379, dtype: float64

# %%
df.iloc[127]
# Out:
# crim         0.25915
# zn           0.00000
# indus       21.89000
# chas         0.00000
# nox          0.62400
# rm           5.69300
# age         96.00000
# dis          1.78830
# rad          4.00000
# tax        437.00000
# ptratio     21.20000
# b          392.11000
# lstat       17.19000
# medv        16.20000
# Name: 127, dtype: float64

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (404, 13)
# (102,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (404, 13)
# y_train shape: (404,)

# %%
X = df.drop(columns=['crim'])
y = df['tax']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (379, 13)
# y_train shape: (379,)

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([ 1.21064218e-15,  5.66213743e-15,  3.26783956e-15,  2.10687479e-13,
#         1.21317886e-14, -2.77555756e-16,  3.18148285e-15, -1.24830701e-14,
#         1.00000000e+00, -9.28077060e-16,  9.71445147e-16, -4.85722573e-17,
#        -2.77555756e-17])

# %%
regressor.intercept_
# Out:
# np.float64(-3.410605131648481e-13)

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred.shape
# Out:
# (127,)

# %%
result = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})

# %%
result
# Out:
#      Actual  Predicted
# 329     430      430.0
# 371     666      666.0
# 219     276      276.0
# 403     666      666.0
# 78      398      398.0
# ..      ...        ...
# 49      233      233.0
# 498     391      391.0
# 309     304      304.0
# 124     188      188.0
# 306     222      222.0
#
# [127 rows x 2 columns]

# %%
residual_error = abs(y_test - y_pred)

# %%
residual_error
# Out:
# 329    0.000000e+00
# 371    3.410605e-13
# 219    1.136868e-13
# 403    3.410605e-13
# 78     5.684342e-14
#            ...
# 49     8.526513e-14
# 498    5.684342e-14
# 309    1.136868e-13
# 124    1.989520e-13
# 306    8.526513e-14
# Name: tax, Length: 127, dtype: float64

# %%
residual_error;

# %%
sum(residual_error)/len(residual_error)
# Out:
# 1.850768007790875e-13

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Plot the first feature of x_train against y_train
plt.scatter(x_train.iloc[:, 0], y_train, color='blue', label='Data points')
plt.xlabel('First Feature')
plt.ylabel('Tax')
plt.title('Scatter plot of first feature vs Tax')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select the first feature of x_train for plotting
x_feature = x_train.iloc[:, 0]

# Calculate the best-fit line (degree 1 polynomial)
slope, intercept = np.polyfit(x_feature, y_train, 1)

# Create the best-fit line
best_fit_line = np.poly1d([slope, intercept])

# Plot the scatter plot
plt.scatter(x_feature, y_train, color='blue', label='Data points')

# Plot the best-fit line
plt.plot(x_feature, best_fit_line(x_feature), color='red', label='Best fit line')

# Label the axes and add a title
plt.xlabel('First Feature')
plt.ylabel('Tax')
plt.title('Scatter plot with Best Fit Line')

# Show the legend
plt.legend()

# Display the plot
plt.show()
